# %% [markdown]
# <a href="https://colab.research.google.com/github/jeenajulius/parallel_coordinates/blob/main/paralel_coordinates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import parallel_coordinates

data = {
    'Age': [24, 29, 35, 36, 70, 18, 65, 45, 50],
    'Salary': [35, 42, 80, 72, 42, 25, 50, 110, 112],
    'Qual': [3, 3, 5, 3, 2, 2, 3, 4, 4]
}
df = pd.DataFrame(data)

plt.figure(figsize=(10, 6))
parallel_coordinates(df, 'Qual', colormap=plt.get_cmap('Set1'))
plt.title('Parallel Coordinates Plot')
plt.xlabel('Features')
plt.ylabel('Values')
plt.xticks(rotation=45)
plt.legend(loc='best')
plt.show()
